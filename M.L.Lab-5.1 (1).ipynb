# %%
x1 = input('enter x1 value:')
x2 = input('enter x2 value:')

if x1 == x2:
    print(0)
else:
    print(1)
# Out:
# enter x1 value:10
# enter x2 value:11
# 1

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image1 = cv2.imread(r'C:\Users\new\Dropbox\My PC (LAPTOP-VOB8LHM1)\Downloads\YS-Jagan.jpg')
image2 = cv2.imread(r'C:\Users\new\Dropbox\My PC (LAPTOP-VOB8LHM1)\Downloads\ysrreddy.jpg')

# %%
imgplot = plt.imshow(image1)
plt.show()

# %%
imgplot = plt.imshow(image2)
plt.show()

# %%
image1 = cv2.resize(image1, (500,500))
image2 = cv2.resize(image2, (500,500))

# %%
imgplot = plt.imshow(image2)
plt.show()

# %%
imgplot = plt.imshow(image1)
plt.show()

# %%
encrypted = cv2.bitwise_xor(image1, image2)
imgplot = plt.imshow(encrypted)
plt.show()

# %%
decrypt = cv2.bitwise_xor(encrypted,image1)
imgplot = plt.imshow(decrypt)
plt.show()
